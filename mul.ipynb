# %%
import pandas as pd
#data=pd.read_csv('H.csv')
data=pd.read_excel('houseprediction.xlsx')
data
# Out:
#     area  roomcount  age     price
# 0    180          5   10   5100000
# 1    225          4   18   5080000
# 2    260          3    2   5480000
# 3    320          6   10   6500000
# 4    335          4    9   6280000
# 5    345          5   14   6320000
# 6    355          3    0   6800000
# 7    400          4   10   7250000
# 8    500          4    0   9200000
# 9    600          3    1  10000000
# 10   650          4    2  12000000

# %%
data.isnull()
# Out:
#      price  crime_rate  resid_area  air_qual  room_num    age  dist1  dist2  \
# 0    False       False       False     False     False  False  False  False
# 1    False       False       False     False     False  False  False  False
# 2    False       False       False     False     False  False  False  False
# 3    False       False       False     False     False  False  False  False
# 4    False       False       False     False     False  False  False  False
# ..     ...         ...         ...       ...       ...    ...    ...    ...
# 501  False       False       False     False     False  False  False  False
# 502  False       False       False     False     False  False  False  False
# 503  False       False       False     False     False  False  False  False
# 504  False       False       False     False     False  False  False  False
# 505  False       False       False     False     False  False  False  False
#
# ...

# %%
data.isnull().sum()
# Out:
# price          0
# crime_rate     0
# resid_area     0
# air_qual       0
# room_num       0
# age            0
# dist1          0
# dist2          0
# dist3          0
# dist4          0
# teachers       0
# poor_prop      0
# airport        0
# n_hos_beds     8
# n_hot_rooms    0
# rainfall       0
# parks          0
# dtype: int64

# %%
data.count()
# Out:
# price          506
# crime_rate     506
# resid_area     506
# air_qual       506
# room_num       506
# age            506
# dist1          506
# dist2          506
# dist3          506
# dist4          506
# teachers       506
# poor_prop      506
# airport        506
# n_hos_beds     498
# n_hot_rooms    506
# rainfall       506
# parks          506
# dtype: int64

# %%
data['n_hos_beds']=data.fillna(data['n_hos_beds'].mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data['n_hos_beds']=data.fillna(data['n_hos_beds'].mean())
#
# File c:\Users\91901\anaconda3\Lib\site-packages\pandas\core\frame.py:3970, in DataFrame.__setitem__(self, key, value)
#    3968     self._setitem_array(key, value)
#    3969 elif isinstance(value, DataFrame):
# -> 3970     self._set_item_frame_value(key, value)
#    3971 elif (
#    3972     is_list_like(value)
#    3973     and not self.columns.is_unique
#    3974     and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    3975 ):
#    3976     # Column to set is duplicated
#    3977     self._setitem_array([key], value)
#
# File c:\Users\91901\anaconda3\Lib\site-packages\pandas\core\frame.py:4100, in DataFrame._set_item_frame_value(self, key, value)
#    4098 len_cols = 1 if is_scalar(cols) else len(cols)
# ...

# %%
df=data.fillna(0)

# %%
df.isnull().sum()
# Out:
# price          0
# crime_rate     0
# resid_area     0
# air_qual       0
# room_num       0
# age            0
# dist1          0
# dist2          0
# dist3          0
# dist4          0
# teachers       0
# poor_prop      0
# airport        0
# n_hos_beds     0
# n_hot_rooms    0
# rainfall       0
# parks          0
# dtype: int64

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#    rainfall     parks
# 0        23  0.049347
# 1        42  0.046146
# 2        38  0.045764
# ...

# %%
data.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
x=df.drop(columns=['price','airport'],axis=True)
x
# Out:
#      crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  dist3  \
# 0       0.00632       32.31     0.538     6.575  65.2   4.35   3.81   4.18
# 1       0.02731       37.07     0.469     6.421  78.9   4.99   4.70   5.12
# 2       0.02729       37.07     0.469     7.185  61.1   5.03   4.86   5.01
# 3       0.03237       32.18     0.458     6.998  45.8   6.21   5.93   6.16
# 4       0.06905       32.18     0.458     7.147  54.2   6.16   5.86   6.37
# ..          ...         ...       ...       ...   ...    ...    ...    ...
# 501     0.06263       41.93     0.573     6.593  69.1   2.64   2.45   2.76
# 502     0.04527       41.93     0.573     6.120  76.7   2.44   2.11   2.46
# 503     0.06076       41.93     0.573     6.976  91.0   2.34   2.06   2.29
# 504     0.10959       41.93     0.573     6.794  89.3   2.54   2.31   2.40
# 505     0.04741       41.93     0.573     6.030  80.8   2.72   2.24   2.64
#
# ...

# %%
y=df['price']
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    19.0
# Name: price, Length: 506, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
x_scaled=std.fit_transform(x)
x_scaled
# Out:
# array([[-0.41978194, -1.2879095 , -0.14421743, ..., -0.35339768,
#         -1.29440816, -0.48076306],
#        [-0.41733926, -0.59338101, -0.74026221, ..., -0.16599956,
#          0.22543063, -0.78218286],
#        [-0.41734159, -0.59338101, -0.74026221, ..., 16.82883914,
#         -0.09453543, -0.81811469],
#        ...,
#        [-0.41344658,  0.11573841,  0.15812412, ..., -0.16248394,
#         -0.65447604,  0.29357329],
#        [-0.40776407,  0.11573841,  0.15812412, ...,  0.40781164,
#          0.62538821,  0.58749353],
#        [-0.41500016,  0.11573841,  0.15812412, ..., -0.55210694,
#          0.46540518,  0.55375216]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=.20,random_state=42)
x_train
# Out:
# array([[ 1.32780421,  1.01599907,  0.51229565, ...,  0.39252631,
#         -0.01454391,  0.70303223],
#        [-0.34750602, -0.43725801, -0.14421743, ...,  0.21353512,
#         -0.89445058,  0.49866437],
#        [-0.41648392, -0.74074945, -1.00891427, ...,  0.21277085,
#         -1.37439968, -0.25397516],
#        ...,
#        [-0.41877066, -1.3316823 , -1.03396543, ...,  0.02949978,
#          0.46540518, -0.52062543],
#        [ 0.87825441,  1.01599907,  1.60072524, ..., -0.17853353,
#          0.5453967 ,  2.10385613],
#        [-0.39389588, -0.37597609, -0.29970737, ...,  0.02048143,
#          1.42530337, -0.01062292]])

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(x_train,y_train)
y_pred=linreg.predict(x_test)
print(y_pred)
# Out:
# [30.60714851 32.75542576 17.77238407 23.97267316 16.76270996 23.60412552
#  17.78860444 14.03334701 21.52709254 21.02197206 21.54270017 19.36009246
#  -5.03407832 23.56443312 18.86129239 25.78202028 19.08754948  3.14189056
#  39.20868783 16.9208762  25.99839667 28.65132444 12.92486925 25.24865151
#  17.24353377 14.70936692 22.95883035 16.8564675  18.95062509 19.34245176
#  22.93695876 25.66081591 25.37276464 16.55825612 14.93978861 19.04995578
#  34.16000674 20.40665852 20.11427225 25.06822126 12.21665396 31.13920649
#  41.10343498 18.29934688 28.25903762 15.48850834 14.70481111 27.01285333
#  18.50364041 30.0967334  21.14330906 33.89329963 16.41262892 27.44391666
#  39.86437219 21.64066693 18.04142738 30.83639759 24.897681   13.33163158
#  21.24024802 28.91350737 31.67961332 17.69127887 20.94938284 14.14721382
#  18.59608424 25.05129394 29.61298566 13.96799487 20.8260172  26.1029333
#  10.1596212  16.79499499 24.72738188  4.01118256 21.47702172 39.11862679
# ...

# %%
from sklearn.metrics import r2_score
print('r2 value=',r2_score(y_test,y_pred))
# Out:
# r2 value= 0.6439010637789917

# %%
import pandas as pd
data=pd.read_csv('House_Price.csv')
data
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0     24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1     21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2     34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3     33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4     36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
# ..     ...         ...         ...       ...       ...   ...    ...    ...
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
# ...

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#    rainfall     parks
# 0        23  0.049347
# 1        42  0.046146
# 2        38  0.045764
# ...

# %%
data.tail()
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 501   2.76   2.06      19.0       9.67      NO       9.348      12.1792
# 502   2.46   2.14      19.0       9.08     YES       6.612      13.1648
# 503   2.29   1.98      19.0       5.64      NO       5.478      12.1912
# 504   2.40   2.31      19.0       6.48     YES       7.940      15.1760
# 505   2.64   2.42      19.0       7.88     YES      10.280      10.1520
#
#      rainfall     parks
# 501        27  0.056006
# 502        20  0.059903
# ...

# %%
import pandas as pd
df=pd.read_csv('D:\\AIML\\Ml lab programs\\multilinear\\House_Price.csv')
df
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0     24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1     21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2     34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3     33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4     36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
# ..     ...         ...         ...       ...       ...   ...    ...    ...
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
# ...

# %%
import pandas as pd
df=pd.read_excel('houseprediction.xlsx')
df
# Out:
#     area  roomcount  age     price
# 0    180          5   10   5100000
# 1    225          4   18   5080000
# 2    260          3    2   5480000
# 3    320          6   10   6500000
# 4    335          4    9   6280000
# 5    345          5   14   6320000
# 6    355          3    0   6800000
# 7    400          4   10   7250000
# 8    500          4    0   9200000
# 9    600          3    1  10000000
# 10   650          4    2  12000000

# %%
df.shape
# Out:
# (11, 4)

# %%
df.isnull()
# Out:
#      area  roomcount    age  price
# 0   False      False  False  False
# 1   False      False  False  False
# 2   False      False  False  False
# 3   False      False  False  False
# 4   False      False  False  False
# 5   False      False  False  False
# 6   False      False  False  False
# 7   False      False  False  False
# 8   False      False  False  False
# 9   False      False  False  False
# 10  False      False  False  False

# %%
df.isnull().sum()
# Out:
# area         0
# roomcount    0
# age          0
# price        0
# dtype: int64

# %%
x=df.drop('price',axis=True)
x
# Out:
#     area  roomcount  age
# 0    180          5   10
# 1    225          4   18
# 2    260          3    2
# 3    320          6   10
# 4    335          4    9
# 5    345          5   14
# 6    355          3    0
# 7    400          4   10
# 8    500          4    0
# 9    600          3    1
# 10   650          4    2

# %%
y=df['price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)
x_train
# Out:
#     area  roomcount  age
# 10   650          4    2
# 2    260          3    2
# 1    225          4   18
# 8    500          4    0
# 4    335          4    9
# 7    400          4   10
# 3    320          6   10
# 6    355          3    0

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(x_train,y_train)
y_pred=linreg.predict(x_test)
print(y_pred)
# Out:
# [ 6801981.04202677  4085572.43386842 10865355.19352942]

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.8455301666895242

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test['area'],y_test)
plt.plot(x_test['area'],y_pred,color='red')
plt.show()

# %%
a=int(input('enter area'))
b=int(input('enter room count'))
c=int(input('enter age'))
pre_price=linreg.predict([[a,b,c]])
print('price=',pre_price)
# Out:
# price= [20750640.85557022]
# c:\Users\91901\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
df=pd.read_excel('houseprediction.xlsx')
df
# Out:
#     area  roomcount  age     price
# 0    180          5   10   5100000
# 1    225          4   18   5080000
# 2    260          3    2   5480000
# 3    320          6   10   6500000
# 4    335          4    9   6280000
# 5    345          5   14   6320000
# 6    355          3    0   6800000
# 7    400          4   10   7250000
# 8    500          4    0   9200000
# 9    600          3    1  10000000
# 10   650          4    2  12000000

# %%
df.isnull()
# Out:
#      area  roomcount    age  price
# 0   False      False  False  False
# 1   False      False  False  False
# 2   False      False  False  False
# 3   False      False  False  False
# 4   False      False  False  False
# 5   False      False  False  False
# 6   False      False  False  False
# 7   False      False  False  False
# 8   False      False  False  False
# 9   False      False  False  False
# 10  False      False  False  False

# %%
df.isnull().sum()
# Out:
# area         0
# roomcount    0
# age          0
# price        0
# dtype: int64

# %%
x=df[['area','roomcount','age']]
x
#x=df.drop('price',axis=True)
# Out:
#     area  roomcount  age
# 0    180          5   10
# 1    225          4   18
# 2    260          3    2
# 3    320          6   10
# 4    335          4    9
# 5    345          5   14
# 6    355          3    0
# 7    400          4   10
# 8    500          4    0
# 9    600          3    1
# 10   650          4    2

# %%
y=df['price']
y
# Out:
# 0      5100000
# 1      5080000
# 2      5480000
# 3      6500000
# 4      6280000
# 5      6320000
# 6      6800000
# 7      7250000
# 8      9200000
# 9     10000000
# 10    12000000
# Name: price, dtype: int64

# %%
df.shape
# Out:
# (11, 4)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)
print(x_train.shape)
x_test.shape
# Out:
# (7, 3)
# (4, 3)

# %%
from sklearn.linear_model import LinearRegression
linear=LinearRegression()
linear.fit(x_train,y_train)
y_pred=linear.predict(x_test)
print('prediction values=\n',y_pred)
# Out:
# prediction values=
#  [ 6700638.98327376  4439618.62458348 10258787.95004975 11050934.26512051]

# %%
print('intercept=',linear.intercept_)
print('coff=',linear.coef_)
# Out:
# intercept= 1533005.2885218319
# coff= [ 14046.67398246 103982.82805165 -14170.21210397]

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print('r2 value=',r2)
# Out:
# r2 value= 0.9496006427691087

# %%
newhouseprice_prediction=linear.predict([[700,3,1]])
print('predicted house price=',newhouseprice_prediction)
# Out:
# predicted house price= [11663455.34829591]
# c:\Users\91901\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
area1=int(input('enter area'))
roomcount1=int(input('enter room count'))
age1=int(input('enter age'))
newprice=linear.predict([[area1,roomcount1,age1]])
print('new house price=',newprice)
# Out:
# new house price= [3398231.39831258]
# c:\Users\91901\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
df=pd.read_excel('houseprediction.xlsx')
df
# Out:
#     area  roomcount  age     price
# 0    180          5   10   5100000
# 1    225          4   18   5080000
# 2    260          3    2   5480000
# 3    320          6   10   6500000
# 4    335          4    9   6280000
# 5    345          5   14   6320000
# 6    355          3    0   6800000
# 7    400          4   10   7250000
# 8    500          4    0   9200000
# 9    600          3    1  10000000
# 10   650          4    2  12000000

# %%
df.shape
# Out:
# (11, 4)

# %%
x=df[['area','roomcount','age']]
x
# Out:
#     area  roomcount  age
# 0    180          5   10
# 1    225          4   18
# 2    260          3    2
# 3    320          6   10
# 4    335          4    9
# 5    345          5   14
# 6    355          3    0
# 7    400          4   10
# 8    500          4    0
# 9    600          3    1
# 10   650          4    2

# %%
y=df['price']
print('dependent features are=\n',y)
# Out:
# dependent features are=
#  0      5100000
# 1      5080000
# 2      5480000
# 3      6500000
# 4      6280000
# 5      6320000
# 6      6800000
# 7      7250000
# 8      9200000
# 9     10000000
# 10    12000000
# Name: price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)
x_train
print(x_train.shape)
x_test.shape
# Out:
# (7, 3)
# (4, 3)

# %%
from sklearn.linear_model import LinearRegression
linear=LinearRegression()
linear.fit(x_train,y_train)
y_pred=linear.predict(x_test)
print('predicted values are=\n',y_pred)
print('intercept=',linear.intercept_)
coff=linear.coef_
print('coff value=',coff)
# Out:
# predicted values are=
#  [ 6700638.98327376  4439618.62458348 10258787.95004975 11050934.26512051]
# intercept= 1533005.2885218319
# coff value= [ 14046.67398246 103982.82805165 -14170.21210397]

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print('r2 value=',r2)
# Out:
# r2 value= 0.9496006427691087

# %%
newhouse_price=linear.predict([[500,3,1]])
print('predicted house price=',newhouse_price)
# Out:
# predicted house price= [8854120.5518036]
# c:\Users\91901\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
areah=int(input('enter area'))
roomcounth=int(input('enter room count'))
ageh=int(input('enter age of the house'))
print('new predicted house=',linear.predict([[areah,roomcounth,ageh]]))
# Out:
# new predicted house= [14576772.97283987]
# c:\Users\91901\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
